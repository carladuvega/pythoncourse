# %% [markdown]
# Comparison Operators
#
#
# ![image.png](attachment:e0666cd0-9712-4fcb-8f0f-c033755177c8.png)

# %% [markdown]
# EQUALITY ==

# %%
2==2
# Out:
# True

# %%
2==1
# Out:
# False

# %% [markdown]
# Operators are used not just for numbers but basically any object

# %%
'hello'=='bye'
# Out:
# False

# %% [markdown]
# When comparing STRINGS, capitalization counts

# %%
'Bye' == 'bye'
# Out:
# False

# %% [markdown]
# When comparing types, it also counts

# %%
'2' == 2
# Out:
# False

# %% [markdown]
# Floating point and integers as long as they have the same value

# %%
2.0==2
# Out:
# True

# %% [markdown]
# INEQUALITY !=

# %%
3 != 3
# Out:
# False

# %%
4 !=5
# Out:
# True

# %% [markdown]
# OTHER OPERATORS:

# %%
3 < 4
# Out:
# True

# %%
4 > 5
# Out:
# False

# %%
2 >= 2
# Out:
# True

# %%
4 <= 1
# Out:
# False

# %% [markdown]
# LOGICAL OPERATORS:
# KEYWORDS:
# AND
# OR
# NOT

# %%
1 < 2
# Out:
# True

# %%
2 < 3
# Out:
# True

# %%
1 < 2 < 3
# Out:
# True

# %%
1 < 2 > 3
# Out:
# False

# %% [markdown]
# EL EJEMPLO ANTERIOR: COMPARA LA PRIMERA OPERACIÓN (1<2) QUE ES VERDADERO, PERO AL COMPARAR LA SEGUNDA (2>3), AL FINAL EL BOOLEAN QUEDA FALSO PORQUE YA LA SEGUNDA OPERACIÓN AFECTA A TODO.

# %% [markdown]
# AND KEYWORD: NEEDS BOTH CONDITIONS TO BE TRUE (LEFT AND RIGHT), OTHERWISE THE BOOLEAN WILL BE FALSE

# %%
1<2 and 2<3
# Out:
# True

# %%
1 < 2 and 2 > 3
# Out:
# False

# %%
'h' == 'h' and 2==2
# Out:
# True

# %% [markdown]
# OR KEYWORD: ONLY NEEDS ONE OF THE CONDITIONS TO BE TRUE

# %%
1 == 1 or 2 == 2
# Out:
# True

# %%
100 == 1 or 2 ==2
# Out:
# True

# %%
100 == 1 or 200 == 2
# Out:
# False

# %% [markdown]
# NOT KEYWORD: IT JUST ASKS TO RETURN THE OPPOSITE BOOLEAN OF WHAT (I) JUST DID

# %%
1 == 1
# Out:
# True

# %%
not 1 == 1
# Out:
# False

# %%
400 > 5000
# Out:
# False

# %%
not 400 > 5000
# Out:
# True
